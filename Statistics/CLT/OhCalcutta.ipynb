# %% [markdown]
# # OhCalcutta
#
# This problem is inspired from Dr C.R.Rao's "Statistics and Truth"
#
# **Problem:** You are asked to estimate the total urban population in the world. You are given that there a total of 6148 cities in the world with population more than 100000. (N=6148)
#
# **Challenge:**
# 1. You cannot do a census in each city. You can only do a census in a sample of the cities.
# 2. You don't know anything prior about the distribution of data.
#
# **Approach:**
# If you can calculate the mean population of a city, then you can multiply it with total number of cities (N) to estimate the total urban population.
#
# So, you have to estimate mean - Would CLT help?
#
# Theorotically yes. The sampling distribution of means should follow normal distribution, whose mean would be population_mean
#
# Data downloaded from [simplemaps.com](https://simplemaps.com/data/world-cities)

# %%
import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
df = pd.read_csv("worldcities.csv")
df = df[df.population > 100000].reset_index(drop=True)
N = df.shape[0]
print("Total number of cities with more than 100000 population: ", N)
# Out:
# Total number of cities with more than 100000 population:  6148

# %% [markdown]
# You did a simple lottery to select the cities in which you'd conduct a census. You have budget for 40 cities. (n=40)

# %%
sample_size = 40
sample_df = df.sample(sample_size)
sample_df
# Out:
#                       city            city_ascii      lat       lng  \
# 1347           Al Ḩudaydah           Al Hudaydah  14.8022   42.9511
# 1508               Larkana               Larkana  27.5583   68.2111
# 2740           Nelamangala           Nelamangala  13.1020   77.3740
# 4195                  Gulu                  Gulu   2.7817   32.2992
# 4806                  Zama                  Zama  35.4833  139.4000
# 4023               Huaycan               Huaycan -12.0181  -76.8139
# 5289               Lodhran               Lodhran  29.5333   71.6333
# 1742                Banjul                Banjul  13.4531  -16.5775
# 5237           Totonicapán           Totonicapan  14.9108  -91.3606
# 6051               Olomouc               Olomouc  49.5939   17.2508
# 3577               Kelowna               Kelowna  49.8881 -119.4956
# 5755               Joyabaj               Joyabaj  14.9950  -90.8075
# 5209                Ebetsu                Ebetsu  43.1000  141.5333
# 5810              Mulhouse              Mulhouse  47.7500    7.3400
# 2352                  Bāli                  Bali  22.6500   88.3400
# 1225          Chimalhuacán          Chimalhuacan  19.4167  -98.9000
# 1434           Santa Marta           Santa Marta  11.2419  -74.2053
# 5344              Erlangen              Erlangen  49.5833   11.0167
# 1130           Makhachkala           Makhachkala  42.9667   47.4833
# 2293              Oulgaret              Oulgaret  11.9570   79.7737
# 657                 Samara                Samara  53.2028   50.1408
# 4757            San Carlos            San Carlos  10.4929  123.4095
# 4595                Kovrov                Kovrov  56.3683   41.3108
# 994                  Natal                 Natal  -5.7833  -35.2000
# 3930           Teresópolis           Teresopolis -22.4119  -42.9658
# 4720              Marituba              Marituba -10.2833  -36.4000
# 5356                 Gabès                 Gabes  33.8833   10.1167
# 5050             Kirishima             Kirishima  31.7406  130.7631
# 4869           Antsiranana           Antsiranana -12.3000   49.2833
# 3959               Haarlem               Haarlem  52.3833    4.6333
# 5996              Caieiras              Caieiras -23.3644  -46.7408
# 654         Salt Lake City        Salt Lake City  40.7776 -111.9311
# 4891           Santo Tomas           Santo Tomas   7.5300  125.6200
# 4375             Jyväskylä             Jyvaskyla  62.2417   25.7417
# 2489              Rockford              Rockford  42.2596  -89.0640
# 943               Dongyang              Dongyang  29.2667  120.2167
# 2062  Vitória da Conquista  Vitoria da Conquista -14.8658  -40.8389
# 4492              Lausanne              Lausanne  46.5198    6.6335
# 5257        Senador Canedo        Senador Canedo -16.7594  -49.0864
# 3900               Singida               Singida  -4.8167   34.7500
#
#             country iso2 iso3             admin_name  capital  population  \
# 1347          Yemen   YE  YEM            Al Ḩudaydah    admin    548433.0
# 1508       Pakistan   PK  PAK                  Sindh    minor    490508.0
# 2740          India   IN  IND              Karnātaka      NaN    245624.0
# 4195         Uganda   UG  UGA                   Gulu    admin    152276.0
# 4806          Japan   JP  JPN               Kanagawa      NaN    130753.0
# 4023           Peru   PE  PER                   Lima      NaN    160000.0
# 5289       Pakistan   PK  PAK                 Punjab    minor    117851.0
# 1742    Gambia, The   GM  GMB                 Banjul  primary    413397.0
# 5237      Guatemala   GT  GTM            Totonicapán    admin    118960.0
# 6051        Czechia   CZ  CZE         Olomoucký Kraj    admin    101825.0
# 3577         Canada   CA  CAN       British Columbia      NaN    181380.0
# 5755      Guatemala   GT  GTM                 Quiché    minor    107634.0
# 5209          Japan   JP  JPN               Hokkaidō      NaN    119819.0
# 5810         France   FR  FRA              Grand Est    minor    106341.0
# 2352          India   IN  IND            West Bengal      NaN    293373.0
# 1225         Mexico   MX  MEX                 México    minor    614453.0
# 1434       Colombia   CO  COL              Magdalena    admin    515556.0
# 5344        Germany   DE  DEU                Bavaria    minor    116562.0
# 1130         Russia   RU  RUS               Dagestan    admin    662600.0
# 2293          India   IN  IND             Tamil Nādu      NaN    300104.0
# 657          Russia   RU  RUS     Samarskaya Oblast’    admin   1169719.0
# 4757    Philippines   PH  PHL      Negros Occidental      NaN    132650.0
# 4595         Russia   RU  RUS  Vladimirskaya Oblast’    minor    137594.0
# 994          Brazil   BR  BRA    Rio Grande do Norte    admin    751300.0
# 3930         Brazil   BR  BRA         Rio de Janeiro      NaN    163746.0
# 4720         Brazil   BR  BRA                Alagoas      NaN    133685.0
# 5356        Tunisia   TN  TUN                  Gabès    admin    116323.0
# 5050          Japan   JP  JPN              Kagoshima      NaN    123812.0
# 4869     Madagascar   MG  MDG            Antsiranana    admin    129320.0
# 3959    Netherlands   NL  NLD          Noord-Holland    admin    162543.0
# 5996         Brazil   BR  BRA              São Paulo      NaN    102775.0
# 654   United States   US  USA                   Utah    admin   1173879.0
# 4891    Philippines   PH  PHL        Davao del Norte      NaN    128667.0
# 4375        Finland   FI  FIN            Keski-Suomi    admin    145887.0
# 2489  United States   US  USA               Illinois      NaN    273237.0
# 943           China   CN  CHN               Zhejiang    minor    804398.0
# 2062         Brazil   BR  BRA                  Bahia      NaN    341128.0
# 4492    Switzerland   CH  CHE                   Vaud    admin    141418.0
# 5257         Brazil   BR  BRA                  Goiás    minor    118451.0
# 3900       Tanzania   TZ  TZA                Singida    admin    165492.0
#
#               id
# 1347  1887984890
# 1508  1586678302
# 2740  1356943451
# 4195  1800406007
# 4806  1392313741
# 4023  1604578883
# 5289  1586813871
# 1742  1270723713
# 5237  1320223386
# 6051  1203328061
# 3577  1124080626
# 5755  1320625420
# 5209  1392987572
# 5810  1250218452
# 2352  1356113138
# 1225  1484504936
# 1434  1170715594
# 5344  1276339482
# 1130  1643580480
# 2293  1356242623
# 657   1643205757
# 4757  1608048026
# 4595  1643110693
# 994   1076697777
# 3930  1076000296
# 4720  1076858443
# 5356  1788064276
# 5050  1392003529
# 4869  1450106928
# 3959  1528822178
# 5996  1076000967
# 654   1840021383
# 4891  1608792041
# 4375  1246938345
# 2489  1840009132
# 943   1156259752
# 2062  1076812020
# 4492  1756055099
# 5257  1076337498
# 3900  1834418526

# %% [markdown]
# Great! Now, you can build the confidence interval for the mean. This leverages CLT.

# %%
sample_size = 40

# Sample data
data = np.array(sample_df.population)

# Sample mean
sample_mean = np.mean(data)

# Sample standard deviation
sample_std = np.std(data, ddof=1)  # ddof=1 provides the sample standard deviation

# Confidence level
confidence_level = 0.95

# Degrees of freedom
dof = sample_size - 1

# t-statistic for the confidence level
t_stat = stats.t.ppf((1 + confidence_level) / 2, dof)

# Margin of error
margin_of_error = t_stat * (sample_std / np.sqrt(sample_size))

# Confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print(f"Sample Mean: {sample_mean}")
print(f"Sample Standard Deviation: {sample_std}")
print(f"t-Statistic: {t_stat}")
print(f"Margin of Error: {margin_of_error}")
print(f"{confidence_level*100}% Confidence Interval: {confidence_interval}")
# Out:
# Sample Mean: 297836.825
# Sample Standard Deviation: 281146.28529481083
# t-Statistic: 2.022690911734728
# Margin of Error: 89914.94379141793
# 95.0% Confidence Interval: (207921.88120858208, 387751.76879141794)

# %%
total_pop_CI =  (confidence_interval[0]*N,confidence_interval[1]*N)
print("95% Confidence Interval for total urban population in the world: ", total_pop_CI)
# Out:
# 95% Confidence Interval for total urban population in the world:  (1278303725.6703627, 2383897874.5296373)

# %% [markdown]
# So, from the chosen sample, you would say that the upper bound of total urban population in the world is 238,38,97,875
#
# `238 Crores` or `2.38 Billion`
#
# Now if the inference was right, our true urban population count would be less than or equal to this. Is it?

# %%
df.population.sum() < confidence_interval[1]*N
# Out:
# False

# %%
df.population.sum()
# Out:
# 4132049481.0

# %% [markdown]
# The true urban population from the dataset we considered is 413,20,49,481. `413 Crores` or `4.13 Billion`
#
# We underestimated the urban population by `~2 Billion`
#
# If we are confident that we would always under-estimate this number, then we can do bias correction by adding a required constant. But, would we always underestimate?
#
# Consider a hypothetical sample now of the same size 40. Only a small difference. Let's consider that the city Delhi fell in this sample (it did not previously)

# %%
sample_df = pd.concat([sample_df[:39], pd.DataFrame(df.iloc[2,:]).T])
sample_df.tail()
# Out:
#                       city            city_ascii      lat       lng  \
# 943               Dongyang              Dongyang  29.2667  120.2167
# 2062  Vitória da Conquista  Vitoria da Conquista -14.8658  -40.8389
# 4492              Lausanne              Lausanne  46.5198    6.6335
# 5257        Senador Canedo        Senador Canedo -16.7594  -49.0864
# 2                    Delhi                 Delhi    28.61     77.23
#
#           country iso2 iso3 admin_name capital  population          id
# 943         China   CN  CHN   Zhejiang   minor    804398.0  1156259752
# 2062       Brazil   BR  BRA      Bahia     NaN    341128.0  1076812020
# 4492  Switzerland   CH  CHE       Vaud   admin    141418.0  1756055099
# 5257       Brazil   BR  BRA      Goiás   minor    118451.0  1076337498
# 2           India   IN  IND      Delhi   admin  32226000.0  1356872604

# %% [markdown]
# Lets estimate the total urban population again using the same process used above.

# %%
sample_size = 40

# Sample data
data = np.array(sample_df.population)

# Sample mean
sample_mean = np.mean(data)

# Sample standard deviation
sample_std = np.std(data, ddof=1)  # ddof=1 provides the sample standard deviation

# Confidence level
confidence_level = 0.95

# Degrees of freedom
dof = sample_size - 1

# t-statistic for the confidence level
t_stat = stats.t.ppf((1 + confidence_level) / 2, dof)

# Margin of error
margin_of_error = t_stat * (sample_std / np.sqrt(sample_size))

# Confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print(f"Sample Mean: {sample_mean}")
print(f"Sample Standard Deviation: {sample_std}")
print(f"t-Statistic: {t_stat}")
print(f"Margin of Error: {margin_of_error}")
print(f"{confidence_level*100}% Confidence Interval: {confidence_interval}")

print("---***---")
total_pop_CI =  (confidence_interval[0]*N,confidence_interval[1]*N)
print("95% Confidence Interval for total urban population in the world: ", total_pop_CI)
# Out:
# Sample Mean: 1099349.525
# Sample Standard Deviation: 5055527.237618852
# t-Statistic: 2.022690911734728
# Margin of Error: 1616836.0429511657
# 95.0% Confidence Interval: (-517486.5179511658, 2716185.5679511656)
# ---***---
# 95% Confidence Interval for total urban population in the world:  (-3181507112.363767, 16699108871.763765)

# %% [markdown]
# The upper bound is 1669,91,08,872 - `1669 Crores` or `16.69 Billions` (This is greater than the total population of the world)
#
# The lower bound is negative. We can use commonsense and consider `62 Crores` or `0.62 Billion` as lower bound `(N*min(sample_data))`
#
# This Confidence Interval is nevertheless meaningless for any Urban policy practitioner.
#
# ## Why did we fail in making statisical inference here?
#
# This is the `"Oh Calcutta!"` problem described in the book `"Statistics and Truth"` by `Dr CR Rao.` Nassim Taleb articulated this as the fat tail problem. I wrote about it here: [Taleb Fat tail](https://medium.com/@saikrishna_17904/taleb-fat-tail-aaeda60661d2)
#
# Basically we failed because CLT fails in this case. And CLT is crucial assumption in constructing a Confidence Interval of mean.

# %%
sample_size = 10
sample = df[df.population >= 5000000 ].sample(sample_size)

# Sample data
data = np.array(sample.population)

# Sample mean
sample_mean = np.mean(data)

# Sample standard deviation
sample_std = np.std(data, ddof=1)  # ddof=1 provides the sample standard deviation

# Confidence level
confidence_level = 0.95

# Degrees of freedom
dof = sample_size - 1

# t-statistic for the confidence level
t_stat = stats.t.ppf((1 + confidence_level) / 2, dof)

# Margin of error
margin_of_error = t_stat * (sample_std / np.sqrt(sample_size))

# Confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print(f"Sample Mean: {sample_mean}")
print(f"Sample Standard Deviation: {sample_std}")
print(f"t-Statistic: {t_stat}")
print(f"Margin of Error: {margin_of_error}")
print(f"{confidence_level*100}% Confidence Interval: {confidence_interval}")

print("---***---")
total_pop_CI =  (confidence_interval[0]*N,confidence_interval[1]*N)
print("95% Confidence Interval for total urban population in the world: ", total_pop_CI)
# Out:
# Sample Mean: 10426898.5
# Sample Standard Deviation: 6023991.807712857
# t-Statistic: 2.2621571627409915
# Margin of Error: 4309304.141049111
# 95.0% Confidence Interval: (6117594.358950889, 14736202.641049111)
# ---***---
# 95% Confidence Interval for total urban population in the world:  (37610970118.83006, 90598173837.16994)

# %%
3026050764.7094064+90598173837
# Out:
# 93624224601.70941

# %%
sample
# Out:
#              city    city_ascii      lat       lng     country iso2 iso3  \
# 99      Nangandao     Nangandao  35.3036  113.9268       China   CN  CHN
# 7       São Paulo     Sao Paulo -23.5500  -46.6333      Brazil   BR  BRA
# 89      Singapore     Singapore   1.3000  103.8000   Singapore   SG  SGP
# 51   Kuala Lumpur  Kuala Lumpur   3.1478  101.6953    Malaysia   MY  MYS
# 18   Buenos Aires  Buenos Aires -34.6033  -58.3817   Argentina   AR  ARG
# 25        Chengdu       Chengdu  30.6600  104.0633       China   CN  CHN
# 34        Baoding       Baoding  38.8740  115.4640       China   CN  CHN
# 73     Chattogram    Chattogram  22.3350   91.8325  Bangladesh   BD  BGD
# 121       Rangoon       Rangoon  16.7950   96.1600       Burma   MM  MMR
# 111        Tai’an        Tai'an  36.2020  117.0870       China   CN  CHN
#
#                            admin_name  capital  population          id
# 99                              Henan    minor   5708191.0  1156127660
# 7                           São Paulo    admin  23086000.0  1076532519
# 89                                NaN  primary   5983000.0  1702341327
# 51                       Kuala Lumpur  primary   8911000.0  1458988644
# 18   Buenos Aires, Ciudad Autónoma de  primary  16710000.0  1032717330
# 25                            Sichuan    admin  14645000.0  1156421555
# 34                              Hebei    minor  11544036.0  1156256829
# 73                         Chattogram    admin   7000000.0  1050830722
# 121                            Yangon  primary   5209541.0  1104616656
# 111                          Shandong      NaN   5472217.0  1156095188
